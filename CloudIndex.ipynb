# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# %%
def read_band(path):
    with rasterio.open(path) as src:
        return src.read(1)

def calculate_cloud_index(blue_band, nir_band):
    cloud_index = blue_band / (nir_band + 0.01)
    return cloud_index

# %%
green_path = "C:/Users/HP/Downloads/LC08_L2SP_148047_20230710_20230718_02_T1_SR_B3.tif"  # Green band for NDSI
swir_path = "C:/Users/HP/Downloads/LC08_L2SP_148047_20230710_20230718_02_T1_SR_B6.tif"   # SWIR1 band for NDSI
blue_path = "C:/Users/HP/Downloads/LC08_L2SP_148047_20230710_20230718_02_T1_SR_B2.tif"   # Blue band for cloud index
nir_path = "C:/Users/HP/Downloads/LC08_L2SP_148047_20230710_20230718_02_T1_SR_B5.tif"    # NIR band for cloud index

# %%
def read_ban(path):
    with rasterio.open(path) as src:
        return src.read(1)

def calculate_cloud_inde(blue_band, swir_band):
    cloud_index = blue_band / (swir_band + 0.01)  # High for clouds, low for land and water
    return cloud_index

blue_path = "C:/Users/HP/Downloads/LC08_L2SP_148047_20230710_20230718_02_T1_SR_B2.tif"      # Blue band for cloud detection
swir_path = "C:/Users/HP/Downloads/LC08_L2SP_148047_20230710_20230718_02_T1_SR_B6.tif"      # SWIR1 band for cloud and snow differentiation

blue = read_ban(blue_path).astype(float)
swir = read_ban(swir_path).astype(float)

# Calculate Cloud Index
cloud_index = calculate_cloud_inde(blue, swir)

# Experiment with different thresholds
thresholds = [0.8, 1.0, 1.2, 1.5]

plt.figure(figsize=(15, 8))
for i, threshold in enumerate(thresholds, 1):
    cloud_mask = cloud_index > threshold
    
    plt.subplot(2, len(thresholds), i)
    plt.title(f'Cloud Index Threshold {threshold}')
    plt.imshow(cloud_index, cmap='coolwarm', vmin=0, vmax=2)
    plt.colorbar()

    plt.subplot(2, len(thresholds), i + len(thresholds))
    plt.title(f'Cloud Mask at Threshold {threshold}')
    plt.imshow(cloud_mask, cmap='gray')
    plt.colorbar()

plt.tight_layout()
plt.show()

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

def read_ban(path):
    with rasterio.open(path) as src:
        return src.read(1)

def calculate_cloud_inde(blue_band, nir_band):
    cloud_index = blue_band / (nir_band + 0.01)  # High for clouds, low for land and water
    return cloud_index

blue_path = "C:/Users/HP/Downloads/LC08_L2SP_148047_20230710_20230718_02_T1_SR_B2.tif"      # Blue band for cloud detection
nir_path = "C:/Users/HP/Downloads/LC08_L2SP_148047_20230710_20230718_02_T1_SR_B5.tif"      # NIR1 band for cloud and snow differentiation

blue = read_ban(blue_path).astype(float)
nir = read_ban(nir_path).astype(float)

cloud_index = calculate_cloud_inde(blue, nir)

# Experiment with different thresholds
thresholds = [0.8, 1.0, 1.2, 1.5]

plt.figure(figsize=(15, 8))
for i, threshold in enumerate(thresholds, 1):
    cloud_mask = cloud_index > threshold
    
    plt.subplot(2, len(thresholds), i)
    plt.title(f'Cloud Index Threshold {threshold}')
    plt.imshow(cloud_index, cmap='coolwarm', vmin=0, vmax=2)
    plt.colorbar()

    plt.subplot(2, len(thresholds), i + len(thresholds))
    plt.title(f'Cloud Mask at Threshold {threshold}')
    plt.imshow(cloud_mask, cmap='gray')
    plt.colorbar()

plt.tight_layout()
plt.show()
